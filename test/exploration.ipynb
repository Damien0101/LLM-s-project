# %%
# %pip install pdf2image pytesseract Pillow pypdf

from pdf2image import convert_from_path
import pytesseract
from PIL import Image
from pypdf import PdfReader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#1
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/BOT_WM hey! Admin Portal FR.pdf"

images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/BOT_WM hey! Admin Portal FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! - Admin Portal - For Back Office Technical
#
# TABLE DES MATIERES
#
# 4.1. GENERALITES 1.2. MSISDN DEJA ENR
#
# 1. GENERALITES
#
# 1.1. GENERALITES
#
# Lorsqu'un agent de back-office n'est pas en mesure de résoudre le probléme du client, un agent de back-office (uniquement) peut assigner le case au ' Partner Everis/Digital Apps'
#
# *Case Status: | Open - New “
# “Service Plan: “i
# Customer Impact: [Medium v
# Assigned Team: Paar Ere Ape
# ‘| Assigned To: [
#
# Retour au début de la page
#
# N DEJA ENREGISTRE
#
# 1.2. MSI
#
# ™ Le client n’arrive pas a s’enregistrer avec son numéro de téléphone.
# ™ Peut-étre que le MSISDN est lié a un autre compte (numéro réutilisé,....).
# ™  C’est ici que vous allez utiliser les 2 écrans de recherche.
#
# ™ Dans le ter, vous recherchez le compte client avec son login e-mail.
#
# = Dans le 2éme, vous recherchez avec le MSISDN que le client essaie de lier 4 son compte.
#
# Par contre, ici
#
# nous pouvons
#
# constater que le
#
# ...

# %%
#2
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/BOT_WM hey! Admin Portal NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/BOT_WM hey! Admin Portal NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Admin Portal - For Back Office Technical
#
# INHOUDSOPGAVE
#
# 1.1, ALGEMEEN 1.2. MSISDN REEDS GEREGISTREE
#
# 1.1. ALGEMEEN
#
# Wanneer een back office agent niet in staat is om het probleem van de klant op te lossen, kan (alleen) een Back office agent de case toewijzen aan de ' Partner Everis/Digital Apps’.
#
# “Case Status: Open - New y|
#
# “Service Plan: v
#
# Customer Impact: | Medium v)
#
# Assigned Team: l ary
# *| Assigned To: | 28 '&€
#
# Q Phone number |Q
#
# Terug naar het begin van de pagina
#
# 1.2. MSISDN REEDS GEREGISTREERD
#
# = De Klant is niet in staat zich te registreren met zijn telefoonnummer.
#
# ™  Misschien is de MSISDN gekoppeld aan een andere account (hergebruikt nummer....)-
# ™  Ditis hier waar je de 2 zoekschermen zal gebruiken.
# ™ in de eerste, zoek je naar de klantencode met zijn e-mail login.
#
# ™ Inde tweede zoek je met het MSISDN dat de klant aan zijn rekening probeert te koppelen.
#
# Hier zien we dat
# het MSISDN reeds
# ...

# %%
#3
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/CT hey! Our Offers evolve_Revamp of our Mobile Portfolio! ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/CT hey! Our Offers evolve_Revamp of our Mobile Portfolio! ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey!
#
# FES!
# hey! Coaching Tip
#
# New Mobile portfolio!
#
# hey! ney!
#
# 01/06/2024 Our Offers evolve | Revamp of the hey! Mobile Portfolio 2024!
#
# Say HEY to a NEW MOBILE PORTFOLIO!
# As from 01/06/2024 , our hey! offers EVOLVE!
#
# WHAT WILL CHANGE?
#
# CHANGE N°1:
# As you know, our actual portfolio consists of 3 Tariff Plans: 2GB , 20GB and 80GB.
#
# Instead of 3 TP’s, we will now offer 4 NEW TARIFF PLANS AS FROM ‘st of JUNE 2024 :
#
# hey! mobile S
#
# hey! mobile M
#
# hey! mobile L
#
# hey! mobile XL
#
# 5 GB
#
# 10 GB
#
# 50 GB
#
# 160 GB
#
# 150 Mins of VOICE
# 500 SMS
#
# 300 Mins of VOICE
# 1000 SMS
#
# Unlimited VOICE
# Unlimited SMS
# 20GB in EU
#
# Unlimited VOICE
# Unlimited SMS
# 35GB in EU
#
# 7€ /month
#
# CHANGE N° 2:
#
# 9€ /month
#
# 14€ /month
#
# The hey! BOOST & YOUTH PROMO WILL NO LONGER EXIST!
#
# IMPORTANT INFO:
#
# Customers currently having the Youth promo active, will keep it until they are 26y/old!
#
# ...

# %%
#4
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/CT hey! Our Offers evolve_Revamp of our Mobile Portfolio! FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/CT hey! Our Offers evolve_Revamp of our Mobile Portfolio! FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# escription
#
# Fret! Reg!
# hey! Coaching Tip
#
# New Mobile portfolio!
# hey! hey!
#
# 01/06/2024 Our Offers evolve | Revamp of our Mobile Portfolio 2024!
#
# Le moment est venu !
# hey! introduit un NOUVEAU PORTEFEUILLE MOBILE !
# A partir du 01/06/2024, nos offres hey! évoluent !
#
# QU'EST-CE QUI CHANGE ?
#
# CHANGEMENT 1:
#
# Comme vous le savez, notre portefeuille actuel contient 3 plans tarifaires : 2GB , 20GB et 80GB.
# Au lieu de 3 plans tarifaires, nous proposerons désormais 4 PLANS TARIFAIRES A PARTIR DE CE ‘er
# JUIN 2024 :
#
# hey! mobile S hey! mobile M hey! mobile L hey! mobile XL
# 5 GB 10 GB 50 GB 160 GB
#
# 150 min d'appels 300 min d'appels Appel & SMS illimités | Appels & SMS illimités
# 500 SMS 1000 SMS 20GB en UE 35GB en UE
#
# 7€ Imois 9€ /mois 14€ mois 25€ /mois
#
# 150 min d’appels 300 min d'appels Appels illimités Appels illimités
#
# 500 SMS 1000 SMS SMS illimités SMS illimités
#
# ...

# %%
#5
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/CT hey! Our Offers evolve_Revamp of our Mobile Portfolio! NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/CT hey! Our Offers evolve_Revamp of our Mobile Portfolio! NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Coaching Tip
#
# New Mobile portfolio!
# hey! ney!
#
# 01/06/2024 Our Offers evolve | Revamp of our Mobile Portfolio 2024!
#
# Het is zover!
# Zeg HEY tegen een NIEUWE MOBILE PORTFOLIO!
# Vanaf 01/06/2024 evolueren onze hey! offers!
#
# WAT VERANDERT ER ALLEMAAL?
#
# VERANDERING 1:
#
# Zoals je weet bestaat ons huidige portfolio uit 3 tariefplannen: 2GB , 20GB en 80GB.
#
# In plaats van 3 Tariefplannen zullen we voortaan 4 NIEUWE TARIEFPLANNEN aanbieden VANAF 01
# JUNI 2024 :
#
# hey! mobile S | hey! mobile M hey! mobile L hey! mobile XL
# 5 GB 10 GB 50 GB 160 GB
# Onbeperkt bellen & Onbeperkt bellen &
#
# 150 Belminuten 300 Belminuten
# - e SMS'en SMS'‘en
# 500 SMS‘jes 1000 SMS‘jes 20GB in de EU 35GB in de EU
#
# 7€ /maand 9€ /maand 14€ /maand 25€ /maand
#
#
#
# Page 2 Text:
# 150 min bellen 300 min bellen Onbeperkt bellen Onbeperkt bellen
# 500 SMS'‘jes 1000 SMS'jes Onbeperkt SMS'en Onbeperkt SMS’en
# ...

# %%
#6
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/ENTRA_WM hey! FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/ENTRA_WM hey! FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! - ENTRA
#
# 1.1. A QUOI SERT CETTE METHODE DE TRAVAIL ?
# 2. COMMENT
#
# 2.1. LES TYPES DE CASES QUE VOUS RECEVREZ ?
#
# 2.2. A QUOI RESSEMBLE LE FORMULAIRE WEB
# DANS LE CASE ?
#
# 2.3. COMMENT ENCODER LE FORMULAIRE WEB COMME
# UNE COMMANDE ?
#
# 2.4. COMMENT TRAITER LE CASE APRES
# L'ENCODAGE ?
#
# 3. DES QUESTIONS
#
# 3.1. QUE FAIRE SI VOUS AVEZ DES QUESTIONS ?
#
# 1. QUOI
#
# 1.1. A QUOI SERT CETTE METHODE DE TRAVAIL
#
# MVNO signifie que les cartes hey! utiliseront le réseau Orange et verront donc Orange sur leur écran de téléphone ou
#
# Smartphone.
# C'est un produit basique sans option ni smartphone.
#
# il y a 4 tarifs MOBILE (A partir du 01/06/2024):
#
# ¢ hey! mobile S (5GB) - 7 EURO
#
# e hey! mobile M (10GB) - 9 EURO
#
# e hey! mobile L (50GB) - 14 EURO
#
# e hey! mobile XL (160GB) - 25 EURO
#
# INFO: Les anciens clients 20GB sont maintenant "hey! 20GB boostés" (40GB)
#
#
# Page 2 Text:
# 150 min d’appels
# 500 SMS
# Réseau 4G/5G Orange
#
# 7 €/mois
# ...

# %%
#7
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/ENTRA_WM hey! New Activation Requests SFVL - Other channels FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/ENTRA_WM hey! New Activation Requests SFVL - Other channels FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# HEY! NOUVELLE DEMANDE D'ACTIVATION VIA D'AUTRES CANAUX
# (VENTES)
#
# Cette méthode de travail est applicable pour I'équipe ENTRA a partir du 01/04/2024.
# ENTRA recevra de nouvelles demandes d'autres canaux (Sales) pour encoder les demandes
# hey! mobile/internet dans Salesforce.
#
# TABLE DE MATIERES
#
# DANS PEOPLESOFT
# COMMENT ENCODER LES
# DEMANDES DANS SALESFORCE?
# DEMANDES EN ATTENTE OU
# REJETEES
#
# DANS PEOPLESOFT
#
# Vous pouvez retrouver les cases dans Peoplesoft sous:
#
# LEVEL 1: Internal Use
# LEVEL 2: Provisioning
# LEVEL 3: Hey Sales
#
# Case Information
#
# Case Type: Internal Use Vv
# Quick Code: Provisioning v
# Level 1: Internal Use
# Level 2: Provisioning
#
# “Level 3: Hey Sales v
#
# Top
# COMMENT ENCODER LES DEMANDES DANS SALESFORCE ?
#
# Tous las détails de l'ordre seront envoyés par e-mail. Sur la base de cet e-mail, vous pouvez saisir la nouvelle demande
# d'activation dans Salesforce.
#
# ...

# %%
#8
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Communication guide FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Communication guide FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# L'objectif de ce guide de communication hey ! est de rappeler les regles de communication pour les
# chats/conversations sur les médias sociaux.
#
# 1. Tone Of Voice
# 2. Do's & Dont's
#
# 3. Outbound calls / Appels
# sortants
#
# 4. Public vs. Private
# 5. Template de réponses
#
# 6. Utilisation des emoji's
#
# 1. TONE OF VOICE
#
#
# Page 2 Text:
# Tone
# of
# voice
#
# Le TONE OF VOICE est la fagon dont nous communiquons, et il est profondément aligné sur la personnalité de notre
# marque. Notre tone of voice se manifeste dans chaque expérience que les gens ont avec hey!. Dans la publicité, les
# relations publiques, la communication d'entreprise, les offres, notre site web et oui, mMéme dans un simple courriel ou un
# SMS d'information. Nous rendons tout plus facile avec hey!
#
# Les points d'attention:
#
# ilisez toujou u", is si i i i z uj u ;
# 1) Utilisez toujours "Tu", mais si le client fait des commentaires a ce sujet ou ne l'accepte pas
# passez a "vous".
#
# ...

# %%
#9
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Communication guide NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Communication guide NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# Het doel van deze hey! communication guide is om de communicatieregels voor Sociale Media
# chats/gesprekken nog eens op een rijtje te zetten.
#
# 1. Tone Of Voice
#
# 2. Do's & Dont's
#
# 3. Outbound calls / Uitgaande gesprekken
# 4. Public vs. Private
#
# 5. Template antwoorden
#
# 6. Gebruik van Emoji's
#
# 1. TONE OF VOICE
#
#
# Page 2 Text:
# Tone
# of
# voice
#
# =>
#
# De TONE OF VOICE is de manier waarop wij communiceren en die sterk afgestemd is op onze merkpersoonlijkheid. Onze
# tone of voice is terug te vinden in elke ervaring die mensen met hey! hebben. In reclame, public relations,
# bedrijfscommunicatie, aanbiedingen, onze website en ja, zelfs in een eenvoudige e-mail- of sms-bericht. We maken alles
# eenvoudiger met hey!
#
# Belangrijke aandachtspunten:
#
# 1) Gebruik steeds "Je", maar als de klant hier een opmerking over maakt of dit niet accepteert ,
# schakel dan over naar "u"
#
# 2) Gebruik jouw eigen naam als handtekening
#
# ...

# %%
#10
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Cable Process ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Cable Process ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Cable Process
#
# 5. CABLE PROCESS
#
# 5.1. PEOPLESOFT 5.2. MY HEY ZONE CREATION + LOGIN
#
# 5.3. LAUNCH INFORMATION (28/09/2023) | 5.4. GENERAL INSTALLATION INFORMATION
#
# GO BACK TO MAIN PAGE
#
# 5. CABLE PROCESS
#
# 5.1. PEOPLESOFT
#
# = ORANGE agents: for an hey! customer use always : Interaction log : Transfer to hey!
#
# Action Taken: Not Completed
# Recall Pending Case
# Customer Mood: Self-Care Interaction
# SocMed Outbound
# Succesful
# Transfer to Bus
# Transfer to Orange
# Transfer to Res
#
# “Interaction Status:
#
# IMPORTANT: After an hey! customer has contacted 5000 a note needs to be made in the Worklog: e.g. hey! customer, we're
# unable to help, customer referred to the hey! website.
#
# = Hey! agents : for an ORANGE custoemer, choose the levels in PeopleSoft related to the customer's question => see CASEBOOK .
# IMPORTANT if it was a request for hey! use the levels Internal Use - Incoming request CS - HEY information and choose
# ...

# %%
#11
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - General NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - General NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage General
#
# INHOUDSTAFEL
#
# 1. ALGEMEEN
# . INTRO 1.11, MY HEY APP
#
# . TONE OF VOICE 1.12. HEY! CONVERSATIES IN KHOROS
#
# . COMMUNICATION GUIDE & PRIVATE vs PUBLIC 1.13. HOE CORRECT REAGEREN OP GEVOELIGE ONDERWERPEN?
#
# |. WEBSITE DOWN 1.14. CSAT hey!
#
# FAQ 1.15. HEY! OFFER BESCHIKBAAR IN SHOPS
#
# . TIPS EN COMMUNITY POSTS 1.16. MIGRATIE VAN ZUNY KLANTEN NAAR HEY!
#
# 1.7. SOCIALE GEDRAGSCODE - HAATSPRAAK. 1.17. HEY! - WEEKLY POSTS ON SOCIAL MEDIA
#
# 1.8. AANVRAGEN VOOR PARTNERSCHAP 1.18. 3G PHASE OUT
#
# 1.9. SERVICE MANAGEMENT 1.19. NEW MOBILE PORTFOLIO
#
# 1.10. WANNEER KUNNEN WE EEN HEY! ORDER ENCODEREN IN SALESFORCE?
#
# GA TERUG NAAR HOOFDPAGINA
#
# hey! - WATIS HET?
#
# hey!-klanten worden alleen digitaal geholpen en krijgen:
#
# ¢ Een transparant aanbod met 4 postpaid tariefplannen om uit te kiezen (verschillend van de Orange-tariefplannen!); hey! heeft geen prepaid
# tariefplannen!
#
# ...

# %%
#12
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Mobile Process ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Mobile Process ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Mobile Process
#
# 4. MOBILE PROCESS
#
# 4.1. PEOPLESOFT 4.2. HOW TO ACTIVATE THE SIM
#
# 4.3. SIMSWAP 4.4. E-SIM
#
# 4.5.5G 4.6. VOLUNTARY SUSPENSION
#
# 4.7. IDENTIFICATION 4.8. ERRORS
#
# 4.9. HOW TO SEND THE CONTRACT TO THE CUSTOMER IN SALESFORCE 4.10. TAKE OVER
#
# 4.11. P2P/ SUSPENSION/ REACTIVATION/ PAYPLAN / HOW TO REACTIVATE A HEY! 4.12. HEY! CARD SUSPENSION AFTER THEFT:
# CUSTOMER IN SALESFORCE? WHAT TO DO?
#
# 4.13. SCAN ID DOC 4.14. FOREIGN ID
#
# GO BACK TO MAIN PAGE
#
# 4. MOBILE PROCESS
#
# 4.1. PEOPLESOFT
#
# = ORANGE agents: for an hey! customer use always : Interaction log : Transfer to hey!
#
# Action Taken: Not Completed
#
# Recall Pending Case
# Customer Mood: Self-Care Interaction
# L. : . _ | SocMed Outbound
# Interaction Status: Succesful
# ROR Transfer to Bus
#
# Number — to Orange
#
# ransfer to Res
# [Trnstertoney_———__]
# Whiteboard Linked Case
#
# Save & Return ] val REMIT
#
# ...

# %%
#13
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Mobile Process FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Mobile Process FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Mobile Process
#
# 4. MOBILE PROCESS
#
# 4.1. PEOPLESOFT 4.2. COMMENT ACTIVER LA SIM
#
# 4.3. SIMSWAP 4.4. E-SIM
#
# 4.5.5G 4.6. VOLUNTARY SUSPENSION
# 4.7. IDENTIFICATION 4.8. ERRORS
#
# 4.9. COMMENT ENVOYER LE CONTRAT DU CLIENT VIA SALESFORCE 4.10. TAKE OVER
#
# 4.11. P2P/ SUSPENSION/ REACTIVATION/ PAYPLAN / COMMENT REACTIVER UN CLIENT 4.12. SUSPENSION APRES UN VOL : QUO!
# HEY! DANS SALESFORCE? FAIRE ?
#
# 4.13. SCAN ID DOC 4.14. FOREIGN ID
#
# RETOURNER A LA PAGE PRINCIPALE
#
# 4. MOBILE PROCESS
#
# 4.1. PEOPLESOFT
#
# = AGENT ORANGE: pour un client hey! => utilisez toujours le Interaction log : Transfer to hey!
#
# Action Taken: Not Completed
#
# Recall Pending Case
# Customer Mood: Self-Care Interaction
# SocMed Outbound
# Succesful
# ROR Transfer to Bus
#
# Number — to Orange
#
# ransfer to Res
# ransfer to hey!
# Whiteboard Linked Case
#
# Save & Return
#
# “Interaction Status:
#
# ...

# %%
#14
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Mobile Process NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Mobile Process NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Mobile Process
#
# 4. MOBILE PROCES
#
# 4.1. PEOPLESOFT 4.2. HOE ACTIVEER IK DE SIM
#
# 4.3. SIMSWAP 4.4. E-SIM
#
# 4.5.5G 4.6. VOLUNTARY SUSPENSION
# 4.7. IDENTIFICATIE 4.8. ERRORS
#
# 4.9. HOE STUUR JE HET CONTRACT NAAR DE KLANT IN SALESFORCE 4.10. TAKE OVER
#
# 4.11. P2P/ SUSPENSION/ REACTIVATION/ PAYPLAN/ HOE REACTIVEER JE EEN HEY! 4.12. SUSPENSIE NA DIEFSTAL: WAT MOET
# KLANT IN SALESFORCE? JE DOEN?
#
# 4.13. SCAN IDENTITEITSDOCUMENT 4.14. FOREIGN ID
#
# GA TERUG NAAR HOOFDPAGINA
#
# 4. MOBILE PROCESS
#
# 4.1. PEOPLESOFT
#
# = ORANGE-agenten: Kies voor een Hey! -klant gebruik altijd de : Interaction log : Transfer to hey!
#
# Action Taken: Not Completed
#
# Recall Pending Case
# Customer Mood: Self-Care Interaction
# SocMed Outbound
# Succesful
# ROR Transfer to Bus
#
# Number — to Orange
#
# ransfer to Res
# ransfer to hey!
# Whiteboard Linked Case
#
# Save & Return
#
# “Interaction Status:
#
# ...

# %%
#15
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Promo ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Promo ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Promo
#
# 3. PROMO
#
# 3.1. HEY! BOOST (NOT APPLICABLE ANYMORE AS FROM 01/06/2024!) | 3.2. MEMBER GET MEMBER
#
# 3.3. PROMO / CAMPAIGN / CONTEST 3.4. PROMO TOOLKIT
# 3.5. COMPARISON 3.6. COMPENSATION GRID
#
# GO BACK TO MAIN PAGE
#
# 3. PROMO
#
# Click here for an overview of all the ongoing hey! promo's.
#
# 3.1. HEY! BOOST
#
# UPDATE 01/06/2024:
#
# As from 1 June 2024, hey! will be launching a new Mobile Portfolio where
# the hey BOOST WILL NOT EXIST ANYMORE!
#
# 3.2. MEMBER GET MEMBER
#
# UPDATE: MEMBER GET MEMBER IS NOT APPLICABLE ANYMORE !!!
#
# All can be found here: WM hey! - Member Get Member (MGM) .
#
# Back to the top of the page
#
# 3.3. PROMO / CAMPAIGN / CONTEST
#
# Campaign & Contests
#
# For an overview of the campaigns and contests, see the commercial WM hey! => tab hey! Campaigns
#
#
# Page 2 Text:
# Promo
#
# You can find an overview of all the promo's here WM hey! - Promotions
#
# 3.5. COMPARISON
#
# Back to the top of the page
#
# ...

# %%
#16
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Promo FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Promo FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Promo
#
# 3. PROMO
#
# 3.1, HEY! BOOST (NE PLUS APPLICABLE A PARTIR DU 01/06/2024!) | 3.2. MEMBER GET MEMBER
#
# 3.3. PROMO / CAMPAGNES / CONCOURS 3.4. PROMO TOOLKIT
# 3.5. COMPARAISON 3.6. COMPENSATION GRID
#
# RETOURNER A LA PAGE PRINCIPALE
#
# 3. PROMO
#
# Cliquez ici pour avoir un apercu des promotions hey! en cours.
#
# 3.1, HEY! BOOST
#
# UPDATE 01/06/2024 :
#
# A partir du 1er juin 2024, hey ! lancera un nouveau portefeuille mobile ou le
# hey BOOST N'EXISTERA PLUS !
#
# 3.2. MEMBER GET MEMBER
#
# UPDATE: MEMBER GET MEMBER N'EST PLUS D'APPLICATION !!!
#
# Tous peuvent étre trouvés selon la WM hey! - Member Get Member (MGM) .
#
# Début de la page
#
#
# Page 2 Text:
# 3.3. PROMO / CAMPAIGN / CONTEST
#
# Campaign & Contests
#
# Pour avoir un apercu des campagnes et concours, aller voir la WM hey! => tab hey! Campaigns
#
# Promo
#
# Consultez la B2C: WM hey! - Promotions
#
# Début de la page
#
# 3.5. COMPARISON
#
# hey!
#
# ...

# %%
#17
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Promo NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Promo NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Promo
#
# 3. PROMO
#
# 3.1. HEY! BOOST (NIET MEER VAN BESCHIKBAAR VANAF 01/06/2024!) | 3.2. MEMBER GET MEMBER
#
# 3.3. PROMO / CAMPAGNES / WEDSTRUDEN 3.4. PROMO TOOLKIT
# 3.5. VERGELUKING 3.6. COMPENSATION GRID
#
# GA TERUG NAAR HOOFDPAGINA
#
# 3. PROMO
#
# Klik hier voor een overzicht van alle lopende hey! promo's.
#
# 3.1. HEY! BOOST
#
# UPDATE 01/06/2024:
#
# Vanaf 1 juni 2024 lanceert hey! een nieuwe Mobile Portfolio waarbij de hey
# BOOST vanaf dan NIET MEER ZAL BESTAAN!
#
# 3.2. MEMBER GET MEMBER
#
# UPDATE: MEMBER GET MEMBER IS NIET MEER VAN TOEPASSING !!!
#
# Alle info kan je hier: WM hey! - Member Get Member (MGM) terugvinden.
#
# Terug naar boven
#
#
# Page 2 Text:
# 3.3. PROMO / CAMPAGNES / WEDSTRIJDEN
#
# Campagnes & westrijden
#
# Voor een overzicht van de campagnes en wedstrijden, zie de commerciéle WM hey! => tab hey! Campaigns
#
# Promo
#
# Raadpleeg de B2C: WM hey! - Promotions voor een overzicht van alle promo's.
#
# Terug naar boven
# ...

# %%
#18
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Teams ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Teams ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Teams
#
# 2. TEAMS
#
# 2.1. BOT MOBILE 2.2. PROVISIONING MOBILE
#
# 2.3. BILLING / COLLECTION / PAYMENT | 2.4. RETENTION
#
# 2.5. ENTRA
#
# GO BACK TO MAIN PAGE
#
# 2. TEAMS
#
# 2.1. BOT MOBILE
# Actions in Salesforce for BOT -teams See WM: Technical Trouble Mobile Homepage .
# PAY ATTENTION TO EXCEPTIONS!!
#
# Info: Premium SMS (excluding for bus tickets and Tv-voting) and calls to special numbers are blocked when the subscription is
# activated, again to avoid unpleasant surprises on the bill.
#
# Chez hey! nous bloquons les achats multimédia. Nous n’aimons pas les surprises
# négatives sur les factures de nos clients @
#
# Si tu désires faire un achat via internet ou Playstore / App store, choisis un autre
# moyen de paiement (par carte de crédit ou bancontact par exemple).
#
# ®% Google play, Multimedia
#
# Here the numbers used for Tv-Voting :
#
# = 61xxx TV-voting 2euros
#
# ...

# %%
#19
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Teams FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Teams FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Teams
#
# 2. TEAMS
#
# 2.1. BOT MOBILE 2.2. PROVISIONING MOBILE
#
# 2.3. BILLING / COLLECTION / PAYMENT | 2.4. RETENTION
#
# 2.5. ENTRA
#
# RETOURNER A LA PAGE PRINCIPALE
#
# 2. TEAMS
#
# 2.1. BOT MOBILE
#
# Actions dans Salesforce pour les équipes BOT voir WM MOBILE - Technical Trouble Mobile Homepage
#
# ATTENTION EXCEPTIONS !!
#
# Les SMS Premium (excepté les tickets de bus et votes-TV) et les appels vers les numéros spéciaux sont bloqués a l’activation
# de I' abonnement, ici aussi pour éviter les mauvaises surprises sur la facture.
#
# Chez hey! nous bloquons les achats multimédia. Nous n’aimons pas les surprises
# négatives sur les factures de nos clients ©
#
# Si tu désires faire un achat via internet ou Playstore / App store, choisis un autre
# moyen de paiement (par carte de crédit ou bancontact par exemple).
#
# ®% Google play, Multimedia
#
# Voici les numéros considérés comme " Votes Tv" :
#
# 61xxx Jeux TV 2euros
#
# ...

# %%
#20
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Teams NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Teams NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Teams
#
# 2. TEAMS
#
# 2.1. BOT MOBILE 2.2. PROVISIONING MOBILE
#
# 2.3. BILLING / COLLECTION / PAYMENT | 2.4. RETENTION
#
# 2.5. ENTRA
#
# GA TERUG NAAR HOOFDPAGINA
#
# 2. TEAMS
#
# 2.1. BOT MOBILE
#
# Acties in Salesforce voor BOT -teams zie WM MOBILE - Technical Trouble Mobile Homepage
#
# LET OP VOOR UITZONDERINGEN!!
#
# Info: Premium-sms'jes (uitgezonderd bustickets en Tv-voting) en oproepen naar speciale nummers worden geblokkeerd
# wanneer het abonnement wordt geactiveerd, opnieuw om onaangename verrassingen op de factuur te voorkomen.
#
# Bij hey! worden de multimedia aankopen standaard geblokkeerd op je
# abonnement.
# We houden niet van nare verrassingen op je facturen ©!
#
# Als je toch een aankoop wenst te doen via het internet of Playstore / App store, kies
# dan een andere betalingswijze (via creditcard of bancontact bv.).
#
# @ Google play, Multimedia
#
# Hieronder de nummers die gebruikt zijn voor Tv-Voting:
#
# ...

# %%
#21
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Tools ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Tools ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Tools
#
# 6. TOOLS
#
# 6.1. VISIBILITY IN TOOLS | 6.2. SALESFORCE
#
# 6.3. ADMIN PORTAL TOOL | 6.4. OUT OF BUNDLE SMS NOTIFICATIONS
#
# GO BACK TO MAIN PAGE
#
# 6. TOOLS
#
# 6.1. VISIBILITY IN TOOLS
#
# In the first months, we'll ask you not to use the Orange Love Tool for hey! customers.
#
# We'll probably develop other templates and way to communicate with them later.
#
# How to recognize them?
#
# Salesforce
#
# The Account Name has always the mention HEY Account :
#
# Account Name Status
#
# Matthieu Fores - HEY Account Customer
#
# arent Account Segment
#
# HEY Residential
#
# Latest Refresh Date @
#
# Activation imported account
#
# OMGT
#
# On order level and Global Information - Customer, you'll see in Segment HEY RESIDENTIAL:
#
#
# Page 2 Text:
# VY Onder 106313952
#
# Order Type:Commercial Status Last Update-20/08/2021 10:57:38
# Order Status:COMPLETE Order Stage-ORDER CLOSED
# Creation Date:20/08/2021 10:47:09 egment:H!
#
# [ | | i
#
# ...

# %%
#22
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Tools FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Tools FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Tools
#
# 6. TOOLS
#
# 6.1. VISIBILITE DANS LES TOOLS | 6.2. SALESFORCE
#
# 6.3. ADMIN PORTAL TOOL 6.4. OUT OF BUNDLE NOTIFICATIONS SMS
#
# RETOURNER A LA PAGE PRINCIPALE
#
# 6. TOOLS
#
# 6.1. VISIBILITY IN TOOLS
#
# Au cours des premiers mois, nous vous demanderons de ne pas utiliser l'outil Orange Love pour les clients de Hey !
# Nous développerons probablement d'autres template et moyens de communication avec eux plus tard.
#
# Comment les reconnaitre ?
#
# Salesforce
#
# Le Account Name a toujours la mention HEY Account :
#
# Account Name Status
#
# Matthieu Fores - HEY Account Customer
#
# Parent Account Segment
#
# HEY Residential
#
# Latest Refresh Date @
#
# Activation imported account
#
# OMGT
#
# Au Order level Global Information - customer , vous verrez dans le Segment HEY RESIDENTIAL :
#
#
# Page 2 Text:
# VY Onder 106313952
#
# Order Type:Commercial Status Last Update-20/08/2021 10:57:38
# Order Status:COMPLETE Order Stage-ORDER CLOSED
# ...

# %%
#23
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage - Tools NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage - Tools NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage - Tools
#
# 6. TOOLS
#
# 6.1. ZICHTBAARHEID IN DE TOOLS | 6.2. SALESFORCE
#
# 6.3. ADMIN PORTAL TOOL 6.4. OUT OF BUNDLE SMS NOTIFICATIES
#
# GA TERUG NAAR HOOFDPAGINA
#
# 6. TOOLS
#
# 6.1. VISIBILITY IN TOOLS
#
# In de eerste paar maanden zullen we je vragen om de Orange Love tool niet te gebruiken voor hey!
#
# Waarschijnlijk zullen wij later nog andere sjablonen en manieren om met hen te communiceren ontwikkelen.
#
# Hoe herken je ze?
#
# Salesforce
#
# De Account Name heeft altijd de vermelding HEY Account
#
# Account Name Status
#
# Matthieu Fores - HEY Account Customer
#
# arent Account Segment
#
# HEY Residential
#
# Latest Refresh Date @
#
# Activation imported account
#
# OMGT
#
# In order level en global Information - Customer, zie je in de Segment HEY RESIDENTIAL :
#
#
# Page 2 Text:
# VY Onder 106313952
#
# Order Type:Commercial Status Last Update-20/08/2021 10:57:38
# Order Status:COMPLETE Order Stage-ORDER CLOSED
# ...

# %%
#24
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage ENG.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage ENG.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage
#
# Welcome to the new hey! Homepage, due to the size of this working method we have split this in the following pages, please click to
# be redirected.
#
# TABLE OF CONTENT
#
# 1. GENERAL
#
# Click here for more info on the following topics:
# INTRODUCTION MY HEY APP
# TONE OF VOICE HEY! CONVERSATIONS IN KHOROS
# COMMUNICATION GUIDE & PUBLIC vs PRIVATE HOW TO REACT TO SENSITIVE SUBJECTS ON SOCIAL MEDIA?
# WEBSITE DOWN CSAT hey!
# FAQ HEY! OFFER AVAILABLE IN PHYSICAL SHOPS
# SOCIAL MEDIA CODE OF CONDUCT MIGRATION OF ZUNY CUSTOMERS TO HEY!
# PARTNERSHIP REQUESTS HEY! - WEEKLY POSTS ON SOCIAL MEDIA
# SERVICE MANAGEMENT 3G PHASE OUT
# WHEN CAN WE ENCODE A HEY! ORDER IN SALESFORCE? NEW MOBILE PORTFOLIO 01/06/2024
#
# 2. TEAMS
#
# Click here for more info on the following topics:
# BOT MOBILE PROVISIONING MOBILE
# BILLING / COLLECTION / PAYMENT RETENTION
# ENTRA
#
# 3. PROMO
#
# Click here for more info on the following topics:
# HEY! BOOST MEMBER GET MEMBER
# ...

# %%
#25
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage FR.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage FR.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage
#
# Bienvenue sur la nouvelle page d'accueil du site hey ! en raison de la taille de cette méthode de travail, nous l'avons divisée en
# plusieurs pages, veuillez cliquer pour étre redirigé.
#
# TABLE DES MATIERES
#
# 1. GENERAL
#
# Cliquez ici pour toutes les infos sur les sujets suivants:
# INTRODUCTION MY HEY APP
# TONE OF VOICE CONVERSATIONS HEY! DANS KHOROS
# COMMUNICATION GUIDE & PUBLIC vs PRIVATE SUJETS SENSIBLE VIA LES RESEAUX SOCIAUX
# SITE WEB EN PANNE (WEBSITE DOWN) CSAT hey!
# FAQ LES OFFRES HEY! DISPONIBLES DANS CERTAINES SHOPS
# CHARTE DE COMPORTEMENT - DISCOURS HAINEAUX MIGRATION DES CLIENTS DE ZUNY VERS HEY!
# DEMANDE DE PARTENARIAT HEY! - WEEKLY POSTS ON SOCIAL MEDIA
# SERVICE MANAGEMENT 3G PHASE OUT
#
# QUAND PEUT-ON ENCODER MANUELLEMENT UNE COMMANDE
#
# HEY! DANS SALESFORCE ? NEW MOBILE PORTFOLIO 01/06/2024
#
# 2. TEAMS
# Cliquez ici pour toutes les infos sur les sujets suivants:
# BOT MOBILE PROVISIONING MOBILE
# ...

# %%
#26
pdf_path = "/home/ezgi/Desktop/LLM-s-project/data/pdf/hey! - Homepage NL.pdf"
images = convert_from_path(pdf_path)

for i, image in enumerate(images):
    text = pytesseract.image_to_string(image) 
    print(f"Page {i+1} Text: \n{text}\n")


with open('/home/ezgi/Desktop/LLM-s-project/data/hey! - Homepage NL.json','w') as f:
    for i, image in enumerate(images):
        text = pytesseract.image_to_string(image) 
        f.write(f"Page {i+1} Text:\n{text}\n")
# Out:
# Page 1 Text:
# hey! Homepage
#
# Welkom op de nieuwe hey! Homepage, vanwege de grootte van deze werkwijze hebben we deze opgesplitst in de volgende
# pagina’s, klik erop om te worden doorverwezen.
#
# INTRO
# TONE OF VOICE
#
# COMMUNICATION GUIDE & PRIVATE vs PUBLIC
#
# WEBSITE DOWN
#
# FAQ
#
# SOCIALE GEDRAGSCODE - HAATSPRAAK
# AANVRAGEN VOOR PARTNERSCHAP
# SERVICE MANAGEMENT
#
# WANNEER KUNNEN WE EEN HEY! ORDER ENCODEREN IN
# SALESFORCE?
#
# VERGELIJKING
#
# PEOPLESOFT
# SIMSWAP
#
# 5G
# IDENTIFICATIE
#
# HOE STUUR JE HET CONTRACT NAAR DE KLANT IN
# SALESFORCE
#
# P2P/ SUSPENSION/ REACTIVATION/ PAYPLAN/ HOE
# REACTIVEER JE EEN HEY! KLANT IN SALESFORCE?
#
# SCAN ID DOC
#
# INHOUDSTAFEL
# 1. ALGEMEEN
#
# Klik hier voor alle info over de volgende onderwerpen:
#
# MY HEY APP
# HEY! CONVERSATIES IN KHOROS
#
# HOE CORRECT REAGEREN OP GEVOELIGE
# ONDERWERPEN?
#
# CSAT hey!
# HEY! OFFER BESCHIKBAAR IN SHOPS
# MIGRATIE VAN ZUNY KLANTEN NAAR HEY!
# HEY! - WEEKLY POSTS ON SOCIAL MEDIA
# ...
